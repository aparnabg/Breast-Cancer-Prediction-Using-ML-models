# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('/content/data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave_points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe().transpose()
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave_points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
data.drop(['id'], axis=1 ,inplace=True)

# %%
data = data.rename(columns={'diagnosis': 'target'})
data['target'].replace({'M': '1', 'B': '0'}, inplace=True)
data['target'] = data['target'].astype(int)

# %%
target_count = data['target'].value_counts()

pie_colors = ['#8da0cb', '#FF3333']
bar_colors = ['#8da0cb', '#FF3333']

fig, axs = plt.subplots(1, 2, figsize=(12, 6))


axs[0].pie(target_count, labels=target_count.index, autopct='%1.1f%%', startangle=90, colors=pie_colors)
axs[0].set_title('Target Distribution (Pie Chart)')


axs[1].bar(target_count.index, target_count.values, color=bar_colors)
axs[1].set_xticks(target_count.index)
axs[1].set_xticklabels(['Benign', 'Malignant'])
axs[1].set_xlabel('Target')
axs[1].set_ylabel('Count')
axs[1].set_title('Target Distribution (Bar Plot)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### HISTOGRAM

# %%
df=pd.read_csv("/content/data.csv")

#dividing the dataframe to 3 parts mean variables , standard error (se) variables, worst variables
df_mean = data.iloc[:, 1:11]
df_se = df.iloc[:, 12:22]
df_worst = df.iloc[:, 22:]

# Define the number of bins for histograms using Sturges' rule
bin_count = int(np.ceil(np.log2(len(df))) + 1)
print(f'Number of bins according to Sturge\'s rule: {bin_count}')

fig, axes = plt.subplots(2, 5, figsize=(16, 12), sharey=True)
fig.tight_layout(pad=3.0)
axes = axes.flatten()

for i, feature in enumerate(df_mean.columns):
    sns.histplot(ax=axes[i], data=df_mean, x=feature, bins=bin_count, kde=True, line_kws={'lw': 3})
    axes[i].set_title(f"{feature} - Mean")

plt.show()
# Out:
# Number of bins according to Sturge's rule: 11

# %%
#histograms for each feature in the standard error dataframe
fig, axes = plt.subplots(2, 5, figsize=(16, 12), sharey=True)
fig.tight_layout(pad=3.0)
axes = axes.flatten()

for i, feature in enumerate(df_se.columns):
    sns.histplot(ax=axes[i], data=df_se, x=feature, bins=bin_count, kde=True, line_kws={'lw': 3})
    axes[i].set_title(f"{feature} - Standard Error")

plt.show()

# %%
#histograms for each feature in the worst dataframe
fig, axes = plt.subplots(2, 5, figsize=(16, 12), sharey=True)
fig.tight_layout(pad=3.0)
axes = axes.flatten()

for i, feature in enumerate(df_worst.columns):
    sns.histplot(ax=axes[i], data=df_worst, x=feature, bins=bin_count, kde=True, line_kws={'lw': 3})
    axes[i].set_title(f"{feature} - Worst")

plt.show()

# %% [markdown]
# ### VIOLIN PLOT

# %%
#standardscalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_mean)
df_scaled = pd.DataFrame(df_scaled, columns=df_mean.columns)
y = df['diagnosis']

# Convert dataframe from wide to long format
df_violin = pd.melt(pd.concat([y, df_scaled], axis=1), id_vars='diagnosis', var_name='features', value_name='value')
fig, axes = plt.subplots(2, 5, figsize=(16, 12), sharey=True)
fig.tight_layout(pad=3.0)
axes = axes.flatten()

#violin plots for each feature in the mean dataframe
for i, feature in enumerate(df_mean.columns):
    sns.violinplot(ax=axes[i], data=df_violin[df_violin['features'] == feature], x='features', y='value', hue='diagnosis', split=True)
    axes[i].set_title(f"{feature} - Mean")

plt.show()

# %%
scaler = StandardScaler()
df_se_scaled = scaler.fit_transform(df_se)
df_se_scaled = pd.DataFrame(df_se_scaled, columns=df_se.columns)
df_se_violin = pd.melt(pd.concat([y, df_se_scaled], axis=1), id_vars='diagnosis', var_name='features', value_name='value')

# standard error violin plots
fig, axes = plt.subplots(2, 5, figsize=(16, 12), sharey=True)
fig.tight_layout(pad=3.0)
axes = axes.flatten()
for i, feature in enumerate(df_se.columns):
    sns.violinplot(ax=axes[i], data=df_se_violin[df_se_violin['features'] == feature], x='features', y='value', hue='diagnosis', split=True)
    axes[i].set_title(f"{feature} - Standard Error")

plt.show()

# %%
scaler = StandardScaler()
df_worst_scaled = scaler.fit_transform(df_worst)
df_worst_scaled = pd.DataFrame(df_worst_scaled, columns=df_worst.columns)
df_worst_violin = pd.melt(pd.concat([y, df_worst_scaled], axis=1), id_vars='diagnosis', var_name='features', value_name='value')

#df_worst violin plots
fig, axes = plt.subplots(2, 5, figsize=(16, 12), sharey=True)
fig.tight_layout(pad=3.0)
axes = axes.flatten()
for i, feature in enumerate(df_worst.columns):
    sns.violinplot(ax=axes[i], data=df_worst_violin[df_worst_violin['features'] == feature], x='features', y='value', hue='diagnosis', split=True)
    axes[i].set_title(f"{feature} - Worst")
plt.show()

# %% [markdown]
# # Correlation

# %%
corr_matrix=data.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %%
def high_corr_pairs(corr_matrix, threshold):
    high_corr_pairs = []
    for i in range(len(corr_matrix.columns)):
        for j in range(i, len(corr_matrix.columns)):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                high_corr_pairs.append((corr_matrix.columns[i], corr_matrix.columns[j], corr_matrix.iloc[i, j]))
    if high_corr_pairs:
        for pair in high_corr_pairs:
            print(f"({pair[0]}, {pair[1]}): {pair[2]}")

# %% [markdown]
# In the context of categorical data, Pearson correlation coefficient aren't typically used. Because they are designed to measure linear relationships between continuous variables.

# %% [markdown]
# #  ANOVA

# %%
X=data.drop(['target'], axis=1)
y=data['target']
from sklearn.feature_selection import SelectKBest,f_classif
selector2 = SelectKBest(f_classif, k=10)
selector2.fit(X,y)
X_new = selector2.transform(X)

# %%
plt.figure()
bars=plt.bar(range(len(selector2.scores_)), selector2.scores_)
selected=[]
for bar in bars:
    if selector2.scores_[bars.index(bar)] > 300:
        bar.set_color('r')

plt.xticks(range(len(selector2.scores_)),X.columns, rotation='vertical')
plt.title("ANOVA F-value feature selection")
plt.show()

# %%
X.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
X.columns[selector2.scores_ > 300]
# Out:
# Index(['radius_mean', 'perimeter_mean', 'area_mean', 'compactness_mean',
#        'concavity_mean', 'concave_points_mean', 'radius_worst',
#        'perimeter_worst', 'area_worst', 'compactness_worst', 'concavity_worst',
#        'concave_points_worst'],
#       dtype='object')

# %%
X_selected = X[X.columns[selector2.scores_ > 300]]
X_selected
# Out:
#      radius_mean  perimeter_mean  area_mean  compactness_mean  concavity_mean  \
# 0          17.99          122.80     1001.0           0.27760         0.30010
# 1          20.57          132.90     1326.0           0.07864         0.08690
# 2          19.69          130.00     1203.0           0.15990         0.19740
# 3          11.42           77.58      386.1           0.28390         0.24140
# 4          20.29          135.10     1297.0           0.13280         0.19800
# ..           ...             ...        ...               ...             ...
# 564        21.56          142.00     1479.0           0.11590         0.24390
# 565        20.13          131.20     1261.0           0.10340         0.14400
# 566        16.60          108.30      858.1           0.10230         0.09251
# 567        20.60          140.10     1265.0           0.27700         0.35140
# 568         7.76           47.92      181.0           0.04362         0.00000
#
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'SVM': SVC()
}

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
result={}
results = {}
for name, model in models.items():
    scores = cross_val_score(model,  X_train_scaled, y_train,cv=kfold, scoring='accuracy')
    result[name] = scores.mean()
    model.fit( X_train_scaled, y_train,)
    y_pred = model.predict(X_test_scaled)
    report = classification_report(y_test, y_pred, output_dict=True)
    results[name] = {'accuracy': scores.mean(), 'recall': report['weighted avg']['recall']}



#classification report of every model
for name, model in models.items():
    model.fit( X_train_scaled, y_train,)
    y_pred = model.predict(X_test_scaled)
    report = classification_report(y_test, y_pred)
    print(f'\nClassification Report for {name}:')
    print(report)

#finding best model
for name, score in result.items():
    print(f'{name}: {score:.4f}')
best_model = max(result, key=result.get)
print(f'\nBest Model: {best_model}')
# Out:
# Classification Report for Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        71
#            1       0.95      0.93      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
#
# Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94        71
#            1       0.95      0.84      0.89        43
#
#     accuracy                           0.92       114
#    macro avg       0.93      0.90      0.91       114
# weighted avg       0.92      0.92      0.92       114
#
#
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        71
#            1       0.95      0.93      0.94        43
#
# ...

# %%
from sklearn.metrics import confusion_matrix

best_model_instance = models[best_model]
best_model_instance.fit(X_train_scaled, y_train)
y_pred = best_model_instance.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Best Model')
plt.show()

# %% [markdown]
# Here we can see that even thouth the accuracy is high but the recall for class 1 ( for best model svm it isonly 0.93)ie, malignant.We want to increase recall. That is more important becauzse the malignat cancer is more harmfull. So we want to classify it correctly.Here we can see that the dataset is imbalanced.For that we want to do Data augmentation.So that the data become balanced.Using SMOTE for that.

# %% [markdown]
# # Data augmentation

# %%
from imblearn.combine import SMOTETomek

#SMOTETomek to the training data
smote =  SMOTETomek(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_selected, y)

# %%
target_count = y_resampled.value_counts()

pie_colors = ['#8da0cb', '#FF3333']
bar_colors = ['#8da0cb', '#FF3333']

fig, axs = plt.subplots(1, 2, figsize=(12, 6))


axs[0].pie(target_count, labels=target_count.index, autopct='%1.1f%%', startangle=90, colors=pie_colors)
axs[0].set_title('Data distribution after augmentatio (Pie Chart)')


axs[1].bar(target_count.index, target_count.values, color=bar_colors)
axs[1].set_xticks(target_count.index)
axs[1].set_xticklabels(['Benign', 'Malignant'])
axs[1].set_xlabel('Target')
axs[1].set_ylabel('Count')
axs[1].set_title('Data distribution after augmentatio (Bar Plot)')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'SVM': SVC()
}

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
result={}
results = {}
for name, model in models.items():
    scores = cross_val_score(model,  X_train_scaled, y_train,cv=kfold, scoring='accuracy')
    result[name] = scores.mean()
    model.fit( X_train_scaled, y_train,)
    y_pred = model.predict(X_test_scaled)
    report = classification_report(y_test, y_pred, output_dict=True)
    results[name] = {'accuracy': scores.mean(), 'recall': report['weighted avg']['recall']}



#classification report of every model
for name, model in models.items():
    model.fit( X_train_scaled, y_train,)
    y_pred = model.predict(X_test_scaled)
    report = classification_report(y_test, y_pred)
    print(f'\nClassification Report for {name}:')
    print(report)
#finding best model
for name, score in result.items():
    print(f'{name}: {score:.4f}')
best_model = max(result, key=result.get)
print(f'\nBest Model: {best_model}')
# Out:
# Classification Report for Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        70
#            1       0.99      0.97      0.98        70
#
#     accuracy                           0.98       140
#    macro avg       0.98      0.98      0.98       140
# weighted avg       0.98      0.98      0.98       140
#
#
# Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        70
#            1       0.94      0.91      0.93        70
#
#     accuracy                           0.93       140
#    macro avg       0.93      0.93      0.93       140
# weighted avg       0.93      0.93      0.93       140
#
#
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        70
#            1       0.99      0.97      0.98        70
#
# ...

# %% [markdown]
# ### CONFUSION MATRIX FOR BEST MODEL

# %%
from sklearn.metrics import confusion_matrix

best_model_instance = models[best_model]
best_model_instance.fit(X_train_scaled, y_train)
y_pred = best_model_instance.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Best Model')
plt.show()
